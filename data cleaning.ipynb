# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\home\Desktop\project folder\used_cars_cardekho.xlsx")
df
# Out:
#                                Car Name    Brand  Year        Location  \
# 0                 2024Kia SonetHTK Plus      Kia  2024  Andhra Pradesh
# 1    2023BMW X3xDrive20d Luxury Edition      Bmw  2023  Andhra Pradesh
# 2              2024Toyota HyryderE BSVI   Toyota  2024  Andhra Pradesh
# 3                 2015Hyundai EOND Lite  Hyundai  2015  Andhra Pradesh
# 4           2024Kia SeltosHTX Diesel AT      Kia  2024  Andhra Pradesh
# ..                                  ...      ...   ...             ...
# 395          2023MG AstorSharp CVT BSVI       Mg  2023     West Bengal
# 396             2022Kia SeltosHTX IVT G      Kia  2022     West Bengal
# 397           2014Honda AmazeEX i-Vtech    Honda  2014     West Bengal
# 398         2014Maruti Wagon RLXI BS IV   Maruti  2014     West Bengal
# 399      2017Maruti SwiftLXI Optional-O   Maruti  2017     West Bengal
#
#            Price   KM Driven Fuel Type Transmission
# 0    ₹10.25 Lakh  10,000 kms    Petrol       Manual
# 1    ₹59.50 Lakh   9,800 kms    Diesel    Automatic
# 2    ₹11.60 Lakh   5,000 kms    Petrol       Manual
# 3     ₹1.55 Lakh  63,000 kms    Petrol       Manual
# 4    ₹16.50 Lakh  30,000 kms    Diesel    Automatic
# ..           ...         ...       ...          ...
# 395  ₹12.50 Lakh  18,572 kms    Petrol    Automatic
# 396  ₹11.95 Lakh  36,000 kms    Petrol    Automatic
# 397   ₹3.65 Lakh  21,000 kms    Petrol       Manual
# 398   ₹2.56 Lakh  16,606 kms    Petrol       Manual
# 399   ₹3.71 Lakh   9,381 kms    Petrol       Manual
#
# [400 rows x 8 columns]

# %%
df.head()
# Out:
#                              Car Name    Brand  Year        Location  \
# 0               2024Kia SonetHTK Plus      Kia  2024  Andhra Pradesh
# 1  2023BMW X3xDrive20d Luxury Edition      Bmw  2023  Andhra Pradesh
# 2            2024Toyota HyryderE BSVI   Toyota  2024  Andhra Pradesh
# 3               2015Hyundai EOND Lite  Hyundai  2015  Andhra Pradesh
# 4         2024Kia SeltosHTX Diesel AT      Kia  2024  Andhra Pradesh
#
#          Price   KM Driven Fuel Type Transmission
# 0  ₹10.25 Lakh  10,000 kms    Petrol       Manual
# 1  ₹59.50 Lakh   9,800 kms    Diesel    Automatic
# 2  ₹11.60 Lakh   5,000 kms    Petrol       Manual
# 3   ₹1.55 Lakh  63,000 kms    Petrol       Manual
# 4  ₹16.50 Lakh  30,000 kms    Diesel    Automatic

# %%
df.tail()
# Out:
#                            Car Name   Brand  Year     Location        Price  \
# 395      2023MG AstorSharp CVT BSVI      Mg  2023  West Bengal  ₹12.50 Lakh
# 396         2022Kia SeltosHTX IVT G     Kia  2022  West Bengal  ₹11.95 Lakh
# 397       2014Honda AmazeEX i-Vtech   Honda  2014  West Bengal   ₹3.65 Lakh
# 398     2014Maruti Wagon RLXI BS IV  Maruti  2014  West Bengal   ₹2.56 Lakh
# 399  2017Maruti SwiftLXI Optional-O  Maruti  2017  West Bengal   ₹3.71 Lakh
#
#       KM Driven Fuel Type Transmission
# 395  18,572 kms    Petrol    Automatic
# 396  36,000 kms    Petrol    Automatic
# 397  21,000 kms    Petrol       Manual
# 398  16,606 kms    Petrol       Manual
# 399   9,381 kms    Petrol       Manual

# %%
df.isna()
# Out:
#      Car Name  Brand   Year  Location  Price  KM Driven  Fuel Type  \
# 0       False  False  False     False  False      False      False
# 1       False  False  False     False  False      False      False
# 2       False  False  False     False  False      False      False
# 3       False  False  False     False  False      False      False
# 4       False  False  False     False  False      False      False
# ..        ...    ...    ...       ...    ...        ...        ...
# 395     False  False  False     False  False      False      False
# 396     False  False  False     False  False      False      False
# 397     False  False  False     False  False      False      False
# 398     False  False  False     False  False      False      False
# 399     False  False  False     False  False      False      False
#
#      Transmission
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 395         False
# 396         False
# 397         False
# 398         False
# 399         False
#
# [400 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# Car Name        0
# Brand           0
# Year            0
# Location        0
# Price           0
# KM Driven       0
# Fuel Type       0
# Transmission    0
# dtype: int64

# %%
df.dtypes
# Out:
# Car Name        object
# Brand           object
# Year             int64
# Location        object
# Price           object
# KM Driven       object
# Fuel Type       object
# Transmission    object
# dtype: object

# %%
df['KM Driven'] = df['KM Driven'].str.replace(' kms', '', regex=False)\
                                 .str.replace(',', '', regex=False)\
                                 .astype(float)

# Preview cleaned column
print(df[['KM Driven']].head())
# Out:
#    KM Driven
# 0    10000.0
# 1     9800.0
# 2     5000.0
# 3    63000.0
# 4    30000.0

# %%
def convert_price(x):
    x = str(x).replace('₹', '').replace(',', '').strip()
    if 'Lakh' in x:
        return float(x.replace('Lakh', '').strip()) * 1e5
    elif 'Crore' in x:
        return float(x.replace('Crore', '').strip()) * 1e7
    else:
        return pd.to_numeric(x, errors='coerce')

df['Price'] = df['Price'].apply(convert_price)

# %%
df.head()
# Out:
#                              Car Name    Brand  Year        Location  \
# 0               2024Kia SonetHTK Plus      Kia  2024  Andhra Pradesh
# 1  2023BMW X3xDrive20d Luxury Edition      Bmw  2023  Andhra Pradesh
# 2            2024Toyota HyryderE BSVI   Toyota  2024  Andhra Pradesh
# 3               2015Hyundai EOND Lite  Hyundai  2015  Andhra Pradesh
# 4         2024Kia SeltosHTX Diesel AT      Kia  2024  Andhra Pradesh
#
#        Price  KM Driven Fuel Type Transmission  KM Driven Cleaned
# 0  1025000.0    10000.0    Petrol       Manual            10000.0
# 1  5950000.0     9800.0    Diesel    Automatic             9800.0
# 2  1160000.0     5000.0    Petrol       Manual             5000.0
# 3   155000.0    63000.0    Petrol       Manual            63000.0
# 4  1650000.0    30000.0    Diesel    Automatic            30000.0
